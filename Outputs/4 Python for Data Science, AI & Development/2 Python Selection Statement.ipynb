# %% [markdown]
# # COURSE 4, WEEK 1 (Group Activity)
# Program list - If construct ( Do any 7 ) :
# Due Monday(9 AM)

# %% [markdown]
# 1. Write a PYTHON program that reads a value of n
# and check the number is zero or non zero value.

# %%
n = int(input("Enter the number: "))
if (n <= 0):
    print("The number is a ZERO value, Value: " ,n)
else:
    print("The number is a NON ZERO value, Value: " ,n)
# Out:
# Enter the number: -100
# The number is a ZERO value, Value:  -100

# %% [markdown]
# 2. Write a PYTHON program to find a largest of two numbers.

# %%
numa = int(input("Enter first number: "))
numb = int(input("Enter second number: "))
if(numa > numb):
    print("The largest number is FIRST number: ",numa)
else:
    print("The largest number is SECOND number: ",numb)
# Out:
# Enter first number: 100
# Enter second number: 300
# The largest number is SECOND number:  300

# %% [markdown]
# 3. Write a PYTHON program that reads the number and
# check the no is positive or negative.

# %%
num = int(input("Enter the number to identify positive or negative: "))
if num >= 0:
    print("The number is Positive: ", num)
else:
    print("The number is Negative: ", num)
# Out:
# Enter the number to identify positive or negative: -10000000
# The number is Negative:  -10000000

# %% [markdown]
# 4. Write a PYTHON program to check entered character is vowel
# or consonant.

# %%
userin = input("Enter a character to check if VOWEL/CONSONANT: ")
if(userin == 'a' or userin == 'A'):
    print("The character is VOWEL: ", userin)
elif(userin == 'e' or userin == 'E'):
    print("The character is VOWEL: ", userin)
elif(userin == 'i' or userin == 'I'):
    print("The character is VOWEL: ", userin)
elif(userin == 'o' or userin == 'O'):
    print("The character is VOWEL: ", userin)
elif(userin == 'u' or userin == 'U'):
    print("The character is VOWEL: ", userin)
else:
    print("The character is CONSONANT: ", userin)
# Out:
# Enter a character to check if VOWEL/CONSONANT: P
# The character is CONSONANT:  P

# %% [markdown]
# 5. Write a PYTHON program to evaluate the student performance
# If % is >=90 then Excellent performance
# If % is >=80 then  Very Good performance
# If % is >=70 then Good performance
# If % is >=60 then average performance
# else Poor performance.

# %%
studentperf = int(input("Enter student grade: "))
if(studentperf >=90):
    print("Excellent performance! -> ", str(studentperf) + "%")
elif(studentperf >=80):
    print("Very Good performance! -> ", str(studentperf) + "%")
elif(studentperf >=70):
    print("Good performance! -> ", str(studentperf) + "%")
elif(studentperf >=60):
    print("Poor performance. -> ", str(studentperf) + "%")
else:
    print("Failed. -> ", str(studentperf) + "%")
# Out:
# Enter student grade: 0
# Failed. ->  0%

# %% [markdown]
# 6. Write a PYTHON program to find largest of three numbers.

# %%
numa = int(input("Enter FIRST number: "))
numb = int(input("Enter SECOND number: "))
numc = int(input("Enter THIRD number: "))
if(numa>numb and numa>numc):
    print("Largest is the FIRST number ", numa)
elif(numb>numa and numb>numc):
    print("Largest is the SECOND number ", numb)
elif(numc>numa and numc>numb):
    print("Largest is the THIRD number ", numc)
else:
    print("Invalid input!")
# Out:
# Enter FIRST number: 10
# Enter SECOND number: 20
# Enter THIRD number: 10
# Largest is the SECOND number  20

# %% [markdown]
# 7. Write a PYTHON program to find smallest of three numbers

# %%
numa = int(input("Enter FIRST number: "))
numb = int(input("Enter SECOND number: "))
numc = int(input("Enter THIRD number: "))
if(numa<numb and numa<numc):
    print("Smallest is the FIRST number ", numa)
elif(numb<numa and numb<numc):
    print("Smallest is the SECOND number ", numb)
elif(numc<numa and numc<numb):
    print("Smallest is the THIRD number ", numc)
else:
    print("Invalid input!")
# Out:
# Enter FIRST number: -10
# Enter SECOND number: 10
# Enter THIRD number: -1
# Smallest is the FIRST number  -10

# %% [markdown]
# 8.Write a PYTHON program to check whether number is even or odd.

# %%
num = int(input("Enter an integer:"))
if(num%2==0):
    print("The number is EVEN")
else:
    print("The number is ODD")
# Out:
# Enter an integer:0
# The number is EVEN

# %% [markdown]
# 9.Write a PYTHON program to check a year for leap year.

# %%
year = int(input("Enter a year: "))
if(year%4==0 or year%400==0):
    print("Yes, It is a LEAP YEAR!")
else:
    print("Sorry, it is NOT.")
# Out:
# Enter a year: 1901
# Sorry, it is NOT.

# %% [markdown]
# 10. A company insures its drivers in the following cases:
# - If the driver is married.
# - If the driver is unmarried, male and above 30 years of age.
# - If the driver is unmarried, female and above 25 years of age.
# In all the other cases, the driver is not insured.
# If the marital status, sex and age of the driver are the inputs,
# Write a PYTHON program to determine whether the driver is insured or not

# %%
maritalstat = int(input("Marital Status (Married-[1] Unmarried-[2]): "))
sex = int(input("Sex (Male-[1] Female-[2]): "))
age = int(input("Age: "))
#Married, Male, 30 and above
if(maritalstat == 1 and sex == 1 and age >= 30):
    print("The driver is INSURED.")
#Married, Female, 25 and above
elif(maritalstat == 1 and sex == 2 and age >= 25):
    print("The driver is INSURED.")
#Unmarried, Male, 30 above
elif(maritalstat == 2 and sex == 1 and age > 30):
    print("The driver is INSURED.")
#Unmarried, Female, 25 above
elif(maritalstat == 2 and sex == 2 and age > 25):
    print("The driver is INSURED.")
else:
    print("The driver is NOT INSURED.")
# Out:
# Marital Status (Married-[1] Unmarried-[2]): 1
# Sex (Male-[1] Female-[2]): 1
# Age: 24
# The driver is NOT INSURED.

# %% [markdown]
# # List Exercises

# %% [markdown]
# #Q1 Create a tuple with all participant names in the JDA program

# %%
jda_tuple = ('Anjali','Anitha','Hinduja','Sarika','Vinay','Leo')
print(jda_tuple)
# Out:
# ('Anjali', 'Anitha', 'Hinduja', 'Sarika', 'Vinay', 'Leo')

# %% [markdown]
# #Q2 Convert the tuple into a list called pps_L

# %%
jda_tuple = 'Anjali','Anitha','Hinduja','Sarika','Vinay','Leo'
pps_L = list(jda_tuple)
pps_L
# Out:
# ['Anjali', 'Anitha', 'Hinduja', 'Sarika', 'Vinay', 'Leo']

# %% [markdown]
# #Q3 What is the length of your list

# %%
len(pps_L)
# Out:
# 6

# %% [markdown]
# #Q4 Find the values stored in indexes [3],[5],[4]

# %%
pps_L[3], pps_L[5], pps_L[4]
# Out:
# ('Sarika', 'Leo', 'Vinay')

# %% [markdown]
# #Q5 Check if "Sarah" is in the list

# %%
pps_L
if "Sarah" in pps_L:
  print("Sarah")
else:
  print("Does not exist!")
# Out:
# Does not exist!

# %% [markdown]
# #Q6 Add "Sarah" to your list

# %%
pps_L.append("Sarah")
print(pps_L)
# Out:
# ['Anjali', 'Anitha', 'Hinduja', 'Sarika', 'Vinay', 'Leo', 'Sarah']

# %% [markdown]
# #Q7 Check if "Bashir" is in the list

# %%
pps_L
if "Bashir" in pps_L:
  print("Bashir")
else:
  print("Does not exist!")
# Out:
# Does not exist!

# %% [markdown]
# #Q9 Add "Bashir" to your list

# %%
pps_L.append("Bashir")
print(pps_L)
# Out:
# ['Anjali', 'Anitha', 'Hinduja', 'Sarika', 'Vinay', 'Leo', 'Sarah', 'Bashir']

# %% [markdown]
# #Q10 Find the index of the element "Sarah" in the list

# %%
search = pps_L.index("Sarah")
print(search)
# Out:
# 6

# %% [markdown]
# #Q11 Change the value of the index in Q10 from "Sarah" to "Instructor"

# %%
pps_L[6] = "Bob"
pps_L
# Out:
# ['Anjali', 'Anitha', 'Hinduja', 'Sarika', 'Vinay', 'Leo', 'Bob', 'Bashir']

# %% [markdown]
# #Q12 Find the index of the element "Bashir" in the list

# %%
search = pps_L.index("Bashir")
print(search)
# Out:
# 7

# %% [markdown]
# #Q13 Change the value of the index in Q12 from "Bashir" to "Peer-Mentor"

# %%
pps_L[7] = "Peer-Mentor"
pps_L
# Out:
# ['Anjali', 'Anitha', 'Hinduja', 'Sarika', 'Vinay', 'Leo', 'Bob', 'Peer-Mentor']

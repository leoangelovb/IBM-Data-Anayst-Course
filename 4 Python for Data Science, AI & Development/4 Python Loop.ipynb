# %% [markdown]
# 1. Write a PYTHON program to print the natural numbers up to n

# %%
num = int(input("Enter number limit: "))
i = 1
while (i <= num):
    print(i)
    i = i + 1
# Out:
# Enter number limit: 5
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 2. Write a PYTHON program to print even numbers up to n

# %%
num = int(input("Enter number limit: "))
i = 0
while i <= num:
    if(i%2==0):
        print(i)
        i = i + 1 
    else:
        i = i + 1
# Out:
# Enter number limit: 4
# 2
# 4

# %% [markdown]
# 3. Write a PYTHON program to print odd numbers up to n

# %%
num = int(input("Enter number limit: "))
i = 0
while i <= num:
    if(i%2!=0):
        print(i)
        i = i + 1 
    else:
        i = i + 1
# Out:
# Enter number limit: 4
# 1
# 3

# %% [markdown]
# 4. Write a PYTHON program to print sum of natural numbers up to n.

# %%
num = int(input("Enter number limit: "))
print("I S")
sum = 0
i = 0
while (i <= num):
    sum = i + sum
    print(i, sum)
    i = i + 1
print("Total: ",sum)
# Out:
# Enter number limit: 9
# I S
# 0 0
# 1 1
# 2 3
# 3 6
# 4 10
# 5 15
# 6 21
# 7 28
# 8 36
# 9 45
# Total:  45

# %% [markdown]
# 5. Write a PYTHON program to print sum of odd numbers up to n

# %%
num = int(input("Enter number limit: "))
print("I S")
sum = 0
i = 0
while (i <= num):
    if(i%2!=0):
        sum = i + sum
        print(i, sum)
        i = i + 1
    else:
        i = i + 1
print("Total: ",sum)
# Out:
# Enter number limit: 5
# I S
# 1 1
# 3 4
# 5 9
# Total:  9

# %% [markdown]
# 6. Write a PYTHON program to print sum of even numbers up to n

# %%
num = int(input("Enter number limit: "))
print("I S")
sum = 0
i = 0
while (i <= num):
    if(i%2==0):
        sum = i + sum
        print(i, sum)
        i = i + 1
    else:
        i = i + 1
print("Total: ",sum)
# Out:
# Enter number limit: 6
# I S
# 0 0
# 2 2
# 4 6
# 6 12
# Total:  12

# %% [markdown]
# 7. Write a PYTHON program to print natural numbers up to n in reverse
# order.

# %%
num = int(input("Enter number limit: "))
i = num
while (i >= 1):
    print(i)
    i = i - 1
# Out:
# Enter number limit: 5
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# 8. Write a PYTHON program to print Fibonacci series up to n

# %%
numn = int(input("Enter the limit: "))
n1 = 0
n2 = 1
i = 1
print("Formula: Fn = Fn1 + Fn2\n")
print("\t\t n1   n2")
while(i <= numn):   
    print("Iteration:", i , "\t", n1, "+", n2)#print initial n1 value
    sum = n1 + n2 #add given n values
    n1 = n2 #move n2 value to n1
    n2 = sum #move sum value to n2
    i = i + 1 #increment iteration
# Out:
# Enter the limit: 12
# Formula: Fn = Fn1 + Fn2
#
# 		 n1   n2
# Iteration: 1 	 0 + 1
# Iteration: 2 	 1 + 1
# Iteration: 3 	 1 + 2
# Iteration: 4 	 2 + 3
# Iteration: 5 	 3 + 5
# Iteration: 6 	 5 + 8
# Iteration: 7 	 8 + 13
# Iteration: 8 	 13 + 21
# Iteration: 9 	 21 + 34
# Iteration: 10 	 34 + 55
# Iteration: 11 	 55 + 89
# Iteration: 12 	 89 + 144

# %% [markdown]
# 9. Write a PYTHON program find a factorial of given number.

# %%
num = int(input("Enter a number: "))    
factorial = 1   
i = 1
if num < 0:    
   print(" Factorial does not exist for negative numbers")    
elif num == 0:    
   print("The factorial of 0 is 1")    
else:    
    while(i <= num):
        factorial = factorial*i    
        i = i + 1
        print(i-1, "\tThe factorial of",num,"is",factorial)
# Out:
# Enter a number: 5
# 1 	The factorial of 5 is 1
# 2 	The factorial of 5 is 2
# 3 	The factorial of 5 is 6
# 4 	The factorial of 5 is 24
# 5 	The factorial of 5 is 120

# %% [markdown]
# 10. Write a PYTHON program to check the entered number is prime or not

# %%
num = int(input("Enter a number: "))
i = 2  
x = 0 
while(i < num):
	if (num % i) == 0:
		x = 1
		print(num, "is not a prime number")
		i = i + 1
	if (x == 0):
		print(num, "is a prime number")
	break
# Out:
# Enter a number: 9
# 9 is a prime number

# %% [markdown]
#  11. Write a PYTHON program to find the sum of digits of given number

# %%
Number = int (input ("Please Enter any Number: ")) 
Sum = 0 
while (Number > 0): 
  Reminder = Number % 10 
  print(Reminder)
  Sum = Sum + Reminder 
  print(Sum)
  Number = Number //10 
  print(Number)
print ("n Sum of the digits of Given Number = %d" %Sum)
# Out:
# Please Enter any Number: 100
# 0
# 0
# 10
# 0
# 0
# 1
# 1
# 1
# 0
# n Sum of the digits of Given Number = 1

# %% [markdown]
# 12. Write a PYTHON program to check the entered number is palindrome
# or not

# %%
num = int( input ( " ENTER THE NUMBER: " ) )
temporary = num
rev = 0
# looping the given input and reversing the value
while temporary != 0:
  rev = ( rev * 10 ) + ( temporary % 10 )
  temporary = temporary // 10
if num == rev:
  print( " number is palindrome " )
else:
  print( " number is not palindrome " )
# Out:
#  ENTER THE NUMBER: 123
#  number is not palindrome

# %% [markdown]
# 13. Write a PYTHON program to reverse the given number.

# %%
My_Number = int(input("Please provide the number to be reversed: "))
Reverse_Number = 0
while(My_Number > 0):
  Reminder = My_Number %10
  Reverse_Number = (Reverse_Number *10) + Reminder
  My_Number = My_Number //10
print("Reverse of the provided number is = %d" %Reverse_Number)
# Out:
# Please provide the number to be reversed: 112
# Reverse of the provided number is = 211

# %% [markdown]
# 14. Write a PYTHON program to print the multiplication table

# %%
# Python program to print multiplication table

# take inputs
num = int(input('Display multiplication table of: '))

# print multiplication table
i = 1
while i <= 10:
    print ("%d * %d = %d" %(num, i, num * i))
    i = i+1
# Out:
# Display multiplication table of: 2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %% [markdown]
# 15. Write a PYTHON program to print the largest of n numbers

# %% [markdown]
# 16. Write a PYTHON program to print smallest of n numbers

# %%
input_lst = []
num = int(input("Enter number limit: "))
i = 1
while (i <= num):
    print(i)
    input_lst.append(i)
    i = i + 1
input_lst
